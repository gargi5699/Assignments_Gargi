# %% [markdown]
# # TASK 1

# %% [markdown]
# ### 1. Read this dataset in pandas , mysql and mongodb

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Dell\Downloads\FitBitdata.csv")

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
from sqlalchemy import create_engine
user='root'
password='5699'
host='localhost'
port=3306
database='fitbit'
db=create_engine(f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}")
print("Connection established at",db)
# Out:
# Connection established at Engine(mysql+pymysql://root:***@localhost:3306/fitbit)

# %%
df.to_sql(con=db,name = 'fitbit_data',if_exists = 'replace', index=False)

# %%
df1 = pd.read_sql('select * from fitbit_data',con=db)

# %%
df1
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb+srv://gargi5699:smita5699@cluster0.196m2.mongodb.net/?retryWrites=true&w=majority")
db = client.test

# %%
database = client['fitbit_datset']

# %%
collection = database['data']

# %%
import json

# %%
df.to_json(r'fitbitdata.json')

# %%
with open('fitbitdata.json') as f:
    file_load = json.load(f)
collection.insert_one(file_load)

# %% [markdown]
# ### 2. while creting a table in mysql dont use manual approach to create it  ,always use a automation to create a table in mysql

# %% [markdown]
# ![Screenshot%20%2887%29.png](attachment:Screenshot%20%2887%29.png)

# %% [markdown]
# ### 3. convert all the dates avaible in dataset to timestamp format in pandas and in sql you to convert it in date format

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
df['ActivityDate'] = pd.to_datetime(df['ActivityDate'])

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-03-25       11004       7.110000         7.110000
# 1    1503960366   2016-03-26       17609      11.550000        11.550000
# 2    1503960366   2016-03-27       12736       8.530000         8.530000
# 3    1503960366   2016-03-28       13231       8.930000         8.930000
# 4    1503960366   2016-03-29       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   2016-04-08       23014      20.389999        20.389999
# 453  8877689391   2016-04-09       16470       8.070000         8.070000
# 454  8877689391   2016-04-10       28497      27.530001        27.530001
# 455  8877689391   2016-04-11       10622       8.060000         8.060000
# 456  8877689391   2016-04-12        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df.dtypes
# Out:
# Id                                   int64
# ActivityDate                datetime64[ns]
# TotalSteps                           int64
# TotalDistance                      float64
# TrackerDistance                    float64
# LoggedActivitiesDistance           float64
# VeryActiveDistance                 float64
# ModeratelyActiveDistance           float64
# LightActiveDistance                float64
# SedentaryActiveDistance            float64
# VeryActiveMinutes                    int64
# FairlyActiveMinutes                  int64
# LightlyActiveMinutes                 int64
# SedentaryMinutes                     int64
# Calories                             int64
# dtype: object

# %% [markdown]
# ### 4 . Find out in this data that how many unique id's we have

# %%
len(df.Id.unique())
# Out:
# 35

# %% [markdown]
# ### 5 . which id is one of the active id that you have in whole dataset

# %%
df['Totalactiveminute'] = df['VeryActiveMinutes']+df['FairlyActiveMinutes']+df['LightlyActiveMinutes']

# %%
df.sort_values('Totalactiveminute',ascending=False).iloc[[0]]
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 139  2891001357   2016-04-02        4126           3.22              0.0
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 139                  3.218688                 0.0                       0.0
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 139                 3.22                      0.0                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 139                    0                   720               720      2881
#
#      Totalactiveminute
# 139                720

# %% [markdown]
# ### 6 . how many of them have not logged there activity find out in terms of number of ids

# %%
len(df.groupby('Id')['LoggedActivitiesDistance'].min())
# Out:
# 35

# %% [markdown]
# ### 7 . Find out who is the laziest person id that we have in dataset

# %%
df[df['Calories']>0].sort_values('Calories').iloc[[0]]
# Out:
#             Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 18  1503960366   2016-04-12         224           0.14             0.14
#
#     LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 18                       0.0                 0.0                       0.0
#
#     LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 18                 0.13                      0.0                  0
#
#     FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 18                    0                     9                32        50
#
#     Totalactiveminute
# 18                  9

# %% [markdown]
# ### 8 . Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset

# %%
# according to internet at an average 2500 calories should be burn each day to stay fit
len(df[df['Calories']>2500]['Id'].unique())
# Out:
# 17

# %% [markdown]
# ### 9. how many person are not a regular person with respect to activity try to find out those

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-03-25       11004       7.110000         7.110000
# 1    1503960366   2016-03-26       17609      11.550000        11.550000
# 2    1503960366   2016-03-27       12736       8.530000         8.530000
# 3    1503960366   2016-03-28       13231       8.930000         8.930000
# 4    1503960366   2016-03-29       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   2016-04-08       23014      20.389999        20.389999
# 453  8877689391   2016-04-09       16470       8.070000         8.070000
# 454  8877689391   2016-04-10       28497      27.530001        27.530001
# 455  8877689391   2016-04-11       10622       8.060000         8.060000
# 456  8877689391   2016-04-12        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df['Totalactivedistance'] = df['VeryActiveDistance'] + df['ModeratelyActiveDistance'] + df['LightActiveDistance']

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-03-25       11004       7.110000         7.110000
# 1    1503960366   2016-03-26       17609      11.550000        11.550000
# 2    1503960366   2016-03-27       12736       8.530000         8.530000
# 3    1503960366   2016-03-28       13231       8.930000         8.930000
# 4    1503960366   2016-03-29       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   2016-04-08       23014      20.389999        20.389999
# 453  8877689391   2016-04-09       16470       8.070000         8.070000
# 454  8877689391   2016-04-10       28497      27.530001        27.530001
# 455  8877689391   2016-04-11       10622       8.060000         8.060000
# 456  8877689391   2016-04-12        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
len(df[(df['Totalactiveminute'] == 0) & (df['Totalactivedistance'] == 0)]['Id'].unique())
# Out:
# 15

# %% [markdown]
# ### 10 . who is the thired most active person in this dataset find out those in pandas and in sql both .

# %%
df.sort_values(['Totalactiveminute'],ascending=False).iloc[[2]]
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 142  2891001357   2016-04-05        2063           1.61              0.0
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 142                  1.609344                 0.0                       0.0
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 142                 1.61                      0.0                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 142                    0                   630                99      1144
#
#      Totalactiveminute  Totalactivedistance
# 142                630                 1.61

# %% [markdown]
# ### 11 . who is the 5th most laziest person avilable in dataset find it out

# %%
df[df['Calories']>0].sort_values('Calories').iloc[[4]]
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 122  2347167796   2016-04-12           0            0.0              0.0
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 122                       0.0                 0.0                       0.0
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 122                  0.0                      0.0                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 122                    0                     0               425       399
#
#      Totalactiveminute  Totalactivedistance
# 122                  0                  0.0

# %% [markdown]
# ### 12 . what is a totla acumulative calories burn for a person find out

# %%
df.groupby('Id')['Calories'].sum().to_frame()
# Out:
#             Calories
# Id
# 1503960366     34128
# 1624580081     25705
# 1644430081     29164
# 1844505072     19391
# 1927972279     27048
# 2022484408     29704
# 2026352035     16266
# 2320127002     18385
# 2347167796     30320
# 2873212765     20349
# 2891001357     18187
# 3372868164     18603
# 3977333714     16777
# 4020332650     98412
# 4057192912     60913
# 4319703577     23931
# 4388161847     14442
# 4445114986     31617
# 4558609924     21962
# 4702921684     42322
# 5553957443     21630
# 5577150313     36303
# 6117666160     20993
# 6290855005     21656
# 6391747486     15868
# 6775888955     24523
# 6962181067     29249
# 7007744171     31525
# 7086361926     26124
# 8053475328     31825
# 8253242879     17556
# 8378563200     40274
# 8583815059     19130
# 8792009665     24884
# 8877689391     41414

# %% [markdown]
# # TASK 2

# %% [markdown]
# ### 1 . load this data in sql and in pandas with a relation in sql
# ### 2 . while loading this data you dont have to create a table manually you can use any automated approach to create a table and load a data in bulk in table

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+pymysql://root:5699@localhost/superstore')

# %%
df_orders = pd.read_excel(r'C:\Users\Dell\Downloads\Superstore_USA.xlsx',sheet_name = 'Orders')

# %%
df_orders.head(3)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois    Addison        60101 2012-05-28 2012-05-30
# 1     West        Washington  Anacortes        98221 2010-07-07 2010-07-08
# 2     West        Washington  Anacortes        98221 2011-07-27 2011-07-28
#
#   Profit  Quantity ordered new  Sales Order ID
# ...

# %%
df_orders.to_sql('order_data',con=engine)

# %%
df_return = pd.read_excel(r'C:\Users\Dell\Downloads\Superstore_USA.xlsx',sheet_name = 'Returns')

# %%
df_return.to_sql('return_data',con=engine)

# %%
df_user = pd.read_excel(r'C:\Users\Dell\Downloads\Superstore_USA.xlsx',sheet_name = 'Users')

# %%
df_user.to_sql('user_data',con=engine)

# %% [markdown]
# ### 3 . Find out how return that we ahve recived and with a product id

# %%
order_return = pd.merge(df_orders,df_return)

# %%
order_return.head(3)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0    1359            Low      0.05        5.85           2.27           21
# 1    1950         Medium      0.01        4.91           0.50          117
# 2    1951         Medium      0.09        4.00           1.30          117
#
#           Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Tony Wilkins Winters  Regular Air   Small Business  Office Supplies  ...
# 1           Linda Weiss  Regular Air      Home Office  Office Supplies  ...
# 2           Linda Weiss  Express Air      Home Office  Office Supplies  ...
#
#   State or Province           City Postal Code  Order Date  Ship Date  Profit  \
# 0          New York  New York City       10012  2011-04-20 2011-04-24   -6.82
# 1        Washington        Seattle       98103  2010-04-04 2010-04-06  112.06
# 2        Washington        Seattle       98103  2010-04-04 2010-04-06   16.79
#
# ...

# %%
order_return.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'Status'],
#       dtype='object')

# %%
order_return[['Order ID','Status']]
# Out:
#     Order ID    Status
# 0       9895  Returned
# 1      13959  Returned
# 2      13959  Returned
# 3      36038  Returned
# 4      39490  Returned
# ..       ...       ...
# 93      7107  Returned
# 94      7107  Returned
# 95     42823  Returned
# 96     13638  Returned
# 97     47109  Returned
#
# [98 rows x 2 columns]

# %% [markdown]
# ### 4 . try  to join order and return data both in sql and pandas

# %%
pd.merge(df_orders,df_return)

# for sql query is like this
# select * from order_data join return_data on order_data.OrderID = return_data.OrderID;
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
# ...

# %% [markdown]
# ### 5 . Try to find out how many unique customer that we have

# %%
len(df_orders['Customer ID'].unique())
# for sql
# select count(distinct Customer ID) from order_data;
# Out:
# 2703

# %% [markdown]
# ### 6 . try to find out in how many regions we are selling a product and who is a manager for a respective region

# %%
df_orders['Region'].unique()
# Out:
# array(['Central', 'West', 'East', 'South'], dtype=object)

# %%
df_user
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %% [markdown]
# ### 7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset

# %%
shipmode = df_orders['Ship Mode']

# %%
count = pd.Series(shipmode).value_counts()
count
# Out:
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: Ship Mode, dtype: int64

# %%
df_ship = pd.DataFrame(count)

# %%
(df_ship[['Ship Mode']]/df_ship.sum())*100
# Out:
#                 Ship Mode
# Regular Air     74.644600
# Delivery Truck  13.611288
# Express Air     11.744112

# %% [markdown]
# ### 8 . Create a new coulmn and try to find our a diffrence between order date and shipment date

# %%
df_orders.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# dtype: object

# %%
df_orders['Difference in Date'] = df_orders['Ship Date'] - df_orders['Order Date']

# %%
df_orders
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %% [markdown]
# ### 9 . base on question number 8 find out for which order id we have shipment duration more than 10 days

# %%
df_orders.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# ...

# %%
df_orders['Difference in Date'] = df_orders['Difference in Date'].dt.days.astype(int)

# %%
df_orders[df_orders['Difference in Date']>10]['Order ID']
# Out:
# 643     87215
# 1548    86318
# 1549    86318
# 1678    87957
# 1679    87957
# 1680    87957
# 1697    19556
# 1698    19556
# 1699    19556
# 2515    86177
# 5548    88223
# 5673    88352
# 5859    87572
# 5881    91294
# 8607    86434
# 8609    86436
# 8610    86436
# 8973    87300
# 8982    19841
# 8983    19841
# 8993    19841
# 8996    87300
# 8997    87300
# Name: Order ID, dtype: int64

# %% [markdown]
# ### 10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well

# %%
order_return = pd.concat([df_orders,df_return])

# %%
order_return.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'Difference in Date',
#        'Status'],
#       dtype='object')

# %%
df1 = order_return[order_return['Difference in Date']>15]

# %%
df1
# Out:
#        Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 643   18246.0       Critical      0.05       11.09           5.25
# 1678  20703.0  Not Specified      0.07      130.98          30.00
# 1680  20705.0  Not Specified      0.08      115.99           4.23
# 1697   2703.0  Not Specified      0.07      130.98          30.00
# 1699   2705.0  Not Specified      0.08      115.99           4.23
# 2515  18060.0            Low      0.02        2.21           1.00
# 5673  19005.0            Low      0.06       65.99           2.50
# 5859  24392.0            Low      0.05       29.89           1.99
# 5881  21257.0            Low      0.05        7.99           5.03
# 8607  26351.0         Medium      0.00        8.32           2.38
# 8609  26350.0         Medium      0.07      180.98          55.24
# 8610  26352.0         Medium      0.06        4.20           2.26
# 8973  20750.0            Low      0.06      125.99           8.08
# ...

# %%
pd.merge(df1,df_user)
# Out:
#      Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18246.0       Critical      0.05       11.09           5.25        250.0
# 1   20703.0  Not Specified      0.07      130.98          30.00        637.0
# 2   20705.0  Not Specified      0.08      115.99           4.23        637.0
# 3    2703.0  Not Specified      0.07      130.98          30.00        640.0
# 4    2705.0  Not Specified      0.08      115.99           4.23        640.0
# 5   18060.0            Low      0.02        2.21           1.00        964.0
# 6   21257.0            Low      0.05        7.99           5.03       2153.0
# 7   19005.0            Low      0.06       65.99           2.50       2088.0
# 8    2748.0            Low      0.03       11.97           5.81       3251.0
# 9    2749.0            Low      0.08      195.99           4.20       3251.0
# 10   2750.0            Low      0.06      125.99           8.08       3251.0
# ...

# %% [markdown]
# ### 11 . Gorup by region and find out which region is more profitable

# %%
df_orders.groupby(['Region'])['Profit'].sum().reset_index().sort_values('Profit', ascending = False).max()
# Out:
# Region      West
# Profit    519826
# dtype: object

# %%
# hence west region has more profit

# %% [markdown]
# ### 12 . Try to find out overalll in which country we are giving more didscount

# %%
df_orders.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'Difference in Date'],
#       dtype='object')

# %%
df_orders.groupby('State or Province')['Discount'].sum().reset_index().sort_values('Discount').max()
# Out:
# State or Province    Wyoming
# Discount               52.28
# dtype: object

# %%
# Wyoming is state where more discount is given

# %% [markdown]
# ### 13 . Give me a list of unique postal code

# %%
df_orders['Postal Code'].unique().tolist()
# Out:
# [60101,
#  98221,
#  91776,
#  95123,
#  2724,
#  3110,
#  8101,
#  8109,
#  7203,
#  2907,
#  55372,
#  11787,
#  13210,
#  59405,
#  59601,
#  59801,
#  68005,
#  10012,
#  92653,
#  92677,
#  92530,
#  92630,
#  90712,
#  93534,
#  90260,
#  97405,
#  97526,
#  97030,
#  97123,
#  97303,
#  62002,
#  98373,
#  98052,
#  75019,
#  23834,
#  62701,
#  60107,
#  60477,
#  14150,
#  12180,
#  77642,
#  75080,
#  77471,
#  78664,
#  75088,
#  24153,
#  94043,
#  92563,
#  94559,
#  10177,
#  2917,
#  5401,
#  4070,
#  2331,
#  8830,
#  8701,
#  7470,
#  7481,
#  5201,
#  97035,
#  44708,
#  45231,
#  44105,
#  95687,
#  5451,
#  94591,
#  70056,
#  22102,
#  60601,
#  66209,
#  66215,
#  66502,
#  66062,
#  6510,
#  4401,
#  4005,
#  2129,
#  2038,
#  1852,
#  1752,
#  2067,
#  3820,
#  8618,
#  7644,
#  7110,
#  8861,
#  7095,
#  2895,
#  97128,
#  97504,
#  98103,
#  84118,
#  84041,
#  93277,
#  76903,
#  78207,
#  60004,
#  94952,
#  1510,
#  1106,
#  1880,
#  6401,
#  6360,
# ...

# %% [markdown]
# ### 14 . which customer segement is more profitalble find it out .

# %%
df_orders.groupby('Customer Segment')['Profit'].aggregate('count') # corporate has more profit
# Out:
# Customer Segment
# Consumer          1894
# Corporate         3375
# Home Office       2316
# Small Business    1841
# Name: Profit, dtype: int64

# %% [markdown]
# ### 15 . try to find out the 10th most loss making product catagory

# %%
df_orders.groupby('Product Sub-Category')['Profit'].sum().reset_index().sort_values('Profit',ascending=True).iloc[9]
# since their are only 3 product category i have considered sub-category
# Out:
# Product Sub-Category    Computer Peripherals
# Profit                               87917.8
# Name: 4, dtype: object

# %% [markdown]
# ### 16 . Try to find out 10 top  product with highest margins

# %%
df_orders.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'Difference in Date'],
#       dtype='object')

# %%
df_orders.groupby('Product Name')['Product Base Margin'].sum().reset_index().sort_values('Product Base Margin',ascending=False).iloc[0:9]
# Out:
#                                            Product Name  Product Base Margin
# 557           Global High-Back Leather Tilter, Burgundy                19.98
# 291   BoxOffice By Design Rectangular and Half-Moon ...                18.33
# 260                     Bevis 36 x 72 Conference Tables                16.38
# 142                Adesso Programmable 142-Key Keyboard                15.45
# 95                                          Accessory36                14.11
# 824   Office Star - Mid Back Dual function Ergonomic...                13.64
# 822   Office Star - Contemporary Task Swivel chair w...                13.26
# 761                         Microsoft Internet Keyboard                13.21
# 1001                                       StarTAC 7760                12.98
